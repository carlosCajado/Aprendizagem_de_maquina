# %%
import pandas as pd
import numpy   as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import zero_one_loss

# aprendizagem máquina
from sklearn import preprocessing
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_samples, silhouette_score

sns.set_theme()
Dataset = pd.read_csv('wdbc_normalizacao.csv')
#Dataset.round(2)
Dataset
# Out:
#      0      1      2       3       4        5        6        7        8  \
# 0    1  17.99  10.38  122.80  1001.0  0.11840  0.27760  0.30010  0.14710
# 1    1  20.57  17.77  132.90  1326.0  0.08474  0.07864  0.08690  0.07017
# 2    1  19.69  21.25  130.00  1203.0  0.10960  0.15990  0.19740  0.12790
# 3    1  11.42  20.38   77.58   386.1  0.14250  0.28390  0.24140  0.10520
# 4    1  20.29  14.34  135.10  1297.0  0.10030  0.13280  0.19800  0.10430
# ..  ..    ...    ...     ...     ...      ...      ...      ...      ...
# 564  1  21.56  22.39  142.00  1479.0  0.11100  0.11590  0.24390  0.13890
# 565  1  20.13  28.25  131.20  1261.0  0.09780  0.10340  0.14400  0.09791
# 566  1  16.60  28.08  108.30   858.1  0.08455  0.10230  0.09251  0.05302
# 567  1  20.60  29.33  140.10  1265.0  0.11780  0.27700  0.35140  0.15200
# 568  0   7.76  24.54   47.92   181.0  0.05263  0.04362  0.00000  0.00000
#
#           9  ...      21     22      23      24       25       26      27  \
# 0    0.2419  ...  25.380  17.33  184.60  2019.0  0.16220  0.66560  0.7119
# 1    0.1812  ...  24.990  23.41  158.80  1956.0  0.12380  0.18660  0.2416
# 2    0.2069  ...  23.570  25.53  152.50  1709.0  0.14440  0.42450  0.4504
# 3    0.2597  ...  14.910  26.50   98.87   567.7  0.20980  0.86630  0.6869
# 4    0.1809  ...  22.540  16.67  152.20  1575.0  0.13740  0.20500  0.4000
# ..      ...  ...     ...    ...     ...     ...      ...      ...     ...
# 564  0.1726  ...  25.450  26.40  166.10  2027.0  0.14100  0.21130  0.4107
# 565  0.1752  ...  23.690  38.25  155.00  1731.0  0.11660  0.19220  0.3215
# 566  0.1590  ...  18.980  34.12  126.70  1124.0  0.11390  0.30940  0.3403
# 567  0.2397  ...  25.740  39.42  184.60  1821.0  0.16500  0.86810  0.9387
# 568  0.1587  ...   9.456  30.37   59.16   268.6  0.08996  0.06444  0.0000
#
#          28      29       30
# 0    0.2654  0.4601  0.11890
# 1    0.1860  0.2750  0.08902
# 2    0.2430  0.3613  0.08758
# 3    0.2575  0.6638  0.17300
# 4    0.1625  0.2364  0.07678
# ..      ...     ...      ...
# 564  0.2216  0.2060  0.07115
# 565  0.1628  0.2572  0.06637
# 566  0.1418  0.2218  0.07820
# 567  0.2650  0.4087  0.12400
# 568  0.0000  0.2871  0.07039
#
# [569 rows x 31 columns]

# %% [markdown]
# **Para Validação Dividimos os Dados:**
# - **treino**,75%
# - **teste**, 25%

# %%
from sklearn.model_selection import train_test_split

# Dividindo em treino e teste 85% treino e 15% teste:
D_treino, D_teste = train_test_split(Dataset, test_size=.15, random_state=30) #test_size, por padrão é 25%

print("D_treino: ", D_treino.shape, dict(D_treino.iloc[:, 0].value_counts()))
print("D_teste: ", D_teste.shape, dict(D_teste.iloc[:, 0].value_counts()))
# Out:
# D_treino:  (483, 31) {0: 305, 1: 178}
# D_teste:  (86, 31) {0: 52, 1: 34}

# %%
# visualizar as amostras:
plt.figure(figsize=(4,3))
plt.hist([D_treino.iloc[:, 0], D_teste.iloc[:, 0]], bins=[0,1,2], align='left', rwidth=0.5)
plt.legend(['D_treino','D_teste'])
plt.xlabel('Y'), plt.xticks([0,1])
plt.show()

# %%
# Selecionado os atributos e classes de treino e teste.
X_treino = D_treino.iloc[:, 1:31]
Y_treino = D_treino.iloc[:, 0]
print("D_treino: ", (X_treino.shape, Y_treino.shape))

X_teste = D_teste.iloc[:, 1:31]
Y_teste = D_teste.iloc[:, 0]
print("D_teste: ", (X_teste.shape, Y_teste.shape))
# Out:
# D_treino:  ((483, 30), (483,))
# D_teste:  ((86, 30), (86,))

# %% [markdown]
# **Normalização:**

# %%
def Normalization(x):
        
    return x/x.abs().max()

# %%
X_treino_Normalizado = Normalization(X_treino)
X_teste_Normalizado = Normalization(X_teste)

# %%
# max absolute scaling 
def maxabs_scaling(df):
    return df/df.abs().max()

# max-min scaling
def maxmin_scaling(df):
    return (df-df.min())/(df.max()-df.min())

# z-score scaling
def zscore_scaling(df):
    return (df-df.mean())/df.std(ddof=0)

# IQR based scaling 
def robust_scaling(df):
    IQR = df.quantile(.75) - df.quantile(.25)
    return (df-df.median())/IQR

# %%
kmeans = KMeans(n_clusters=4, n_init='auto', init='random')
kmeans.fit(X_treino_Normalizado)
# Out:
# KMeans(init='random', n_clusters=4)

# %%
# Normalizando os dados
scaler = StandardScaler()
X_treino_Normalizado = scaler.fit_transform(X_treino)
X_teste_Normalizado = scaler.transform(X_teste)

# Selecionar duas características para visualização
X_treino_vis = pd.DataFrame(X_treino_Normalizado[:, [0, 1]], columns=['raio', 'textura'])

# Treinamento do modelo KMeans
kmeans = KMeans(n_clusters=2, n_init='auto', init='random')
kmeans.fit(X_treino_vis)

# Visualização do KMeans
plt.figure(figsize=(10, 8))
scatter = plt.scatter(X_treino_vis['raio'], X_treino_vis['textura'], c=kmeans.labels_, s=20, cmap='viridis', alpha=0.6)

# Plotar centros dos clusters
centers = kmeans.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='white', marker='o', s=100, alpha=1, edgecolor='k')

for i, c in enumerate(centers):
    plt.scatter(c[0], c[1], marker='$%d$' % i, alpha=1, s=30, edgecolor='r')

plt.xlabel('Feature a (raio)')
plt.ylabel('Feature b (textura)')
plt.title('Visualização dos Clusters KMeans')
plt.colorbar(scatter, label='Cluster ID')
plt.show()

# %%
# Análise do Cotovelo
inertia = []
K = range(1, 10)

fig, axs = plt.subplots(3, 3, figsize=(15, 15))
plt.subplots_adjust(wspace=0.2, hspace=0.4) 

for k in K:
    model = KMeans(n_clusters=k, n_init='auto')
    model.fit(X_treino_vis)
    inertia.append(model.inertia_)
    
    axk = axs[int((k-1)/3), ((k-1)%3)]
    axk.set_title(f'k = {k}')
    axk.set_xlabel('Feature b')
    axk.set_ylabel('Feature c')
    scatter = axk.scatter(X_treino_vis['Feature b'], X_treino_vis['Feature c'], c=model.labels_, s=5, cmap='viridis')
    
    centers = model.cluster_centers_
    axk.scatter(centers[:, 0], centers[:, 1], c='red', marker='+', s=50, alpha=1)

# Plotando a análise do cotovelo
plt.figure(figsize=(10, 6))
plt.plot(K, inertia, 'bx-')
plt.xlabel('Número de Clusters (k)')
plt.ylabel('Inércia (SSE)')
plt.title('Análise do Cotovelo do k-Means')
plt.show()

# %%
# Fazendo a previsão para os dados de teste
y_pred = clf.predict(X_teste_Normalizado)

# %%
# Verificando a matriz de confusão
from sklearn.metrics import confusion_matrix
confusion_matrix(Y_teste,y_pred)
# Out:
# array([[49,  3],
#        [ 0, 34]], dtype=int64)

# %%
def teste(g, D_tst, metrica, **kwds):
    X_tst, y_tst = D_tst
    y_true = y_tst
    y_pred = clf.predict(X_tst)
    E_tst = metrica(y_true, y_pred, **kwds)
    
    return E_tst


def validacao(Modelo, D_trn, D_val, metrica, **kwds):
    # Treinamento:
    g = Modelo.fit(*D_trn)
    
    # Teste:
    E_trn = teste(g, D_trn, metrica, **kwds)
    E_val = teste(g, D_val, metrica, **kwds)
    
    return E_trn, E_val

# %%
# Dividindo em  dados de treino e validação 15%
X_train, X_val, y_train, y_val = train_test_split(X_treino_Normalizado, Y_treino, test_size=0.15, random_state=30)

# %%
#Avaliando o modelo: 
E_trn, E_tst = validacao(clf, (X_train, y_train), (X_teste, Y_teste), zero_one_loss)
print("Erro de treinamento:", E_trn)
print("Erro de teste :", E_tst)
# Out:
# Erro de treinamento: 0.034146341463414664
# Erro de teste : 0.6046511627906976

# %%
# Plot matriz de confusão
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
# Avaliação modelo  (matriz de confusão)
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay

cm_trn, cm_tst = validacao(clf, (X_train, y_train), (X_teste_Normalizado, Y_teste), confusion_matrix)

with sns.plotting_context(rc={'grid.linewidth': 0}):
    fig, ax = plt.subplots(ncols=2, figsize=(5,2))
    ConfusionMatrixDisplay(confusion_matrix=cm_trn, display_labels=[0,1]).plot(ax=ax[0], colorbar=False)
    ConfusionMatrixDisplay(confusion_matrix=cm_tst, display_labels=[0,1]).plot(ax=ax[1], colorbar=False)

# %%
# Avaliação modelo  (relatório de classificação)

from sklearn.metrics import classification_report

cr_trn, cr_tst = validacao(clf, (X_train, y_train), (X_teste_Normalizado, Y_teste),
                            classification_report, target_names=['Outcome 0', 'Outcome 1'])
print("treino:\n", cr_trn)
print("teste :\n", cr_tst)
# Out:
# treino:
#                precision    recall  f1-score   support
#
#    Outcome 0       0.95      1.00      0.97       267
#    Outcome 1       1.00      0.90      0.95       143
#
#     accuracy                           0.97       410
#    macro avg       0.98      0.95      0.96       410
# weighted avg       0.97      0.97      0.97       410
#
# teste :
#                precision    recall  f1-score   support
#
#    Outcome 0       1.00      0.96      0.98        52
#    Outcome 1       0.94      1.00      0.97        34
#
#     accuracy                           0.98        86
#    macro avg       0.97      0.98      0.98        86
# weighted avg       0.98      0.98      0.98        86

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

"""
Caracteristicas X_treino
a) raio (média das distâncias do centro aos pontos do perímetro)
  b) textura (desvio padrão dos valores da escala de cinza)
  c) perímetro
  e) área
  e) suavidade (variação local nos comprimentos dos raios)
  f) compacidade (perímetro ^ 2 / área - 1,0)
  g) concavidade (gravidade das porções côncavas do contorno)
  h) pontos côncavos (número de porções côncavas do contorno)
  e) simetria
  j) dimensão fractal ("aproximação da linha costeira" - 1)
  
  SERÁ USADO "b", e "c"
"""


# Scatter plot 3D dos dados de treino
scatter = ax.scatter(X_treino_Normalizado.iloc[:, 1],  # característica "b" (textura)
                     X_treino_Normalizado.iloc[:, 2],  # característica "c" (perímetro)
                     X_treino_Normalizado.iloc[:, 3],  # característica "e" (área)
                     c=Y_treino,           # rótulos de classe
                     cmap='viridis',
                     s=50,                
                     alpha=0.6)             

# Adicionar rótulos aos eixos
ax.set_xlabel('Textura (Feature b)')
ax.set_ylabel('Perímetro (Feature c)')
ax.set_zlabel('Área (Feature e)')

# Adicionar título
plt.title('Grafico 3D - Utilizando Caracteristicas relacionados a Classes')

# Adicionar uma barra de cores para legendar as classes
cbar = plt.colorbar(scatter, ax=ax)
cbar.set_label('Class: (0 = benigno, 1 = maligno)')

plt.show()

# %%
from sklearn.metrics import accuracy_score

# Variando o valor de k de 1 a 10
k_values = range(1, 11)
accuracies = []

for k in k_values:
    clf = KNeighborsClassifier(n_neighbors=k)
    clf.fit(X_treino_Normalizado, Y_treino)
    y_pred = clf.predict(X_teste_Normalizado)
    accuracy = accuracy_score(Y_teste, y_pred)
    accuracies.append(accuracy)
    print(f"k={k}, Acurácia={accuracy:.4f}")

# Plotando os resultados
plt.figure(figsize=(10, 6))
plt.plot(k_values, accuracies, marker='o')
plt.xlabel('Número de Vizinhos k')
plt.ylabel('Acurácia')
plt.title('Acurácia do k-NN Variando o Valor de k')
plt.grid(True)
plt.show()
# Out:
# k=1, Acurácia=0.9419
# k=2, Acurácia=0.9651
# k=3, Acurácia=0.9302
# k=4, Acurácia=0.9535
# k=5, Acurácia=0.9419
# k=6, Acurácia=0.9302
# k=7, Acurácia=0.9302
# k=8, Acurácia=0.9419
# k=9, Acurácia=0.9419
# k=10, Acurácia=0.9419

# %%
def avaliar_knn(k_values, distance_metric, use_weights=False):
    accuracies = []

    for k in k_values:
        if use_weights:
            clf = KNeighborsClassifier(n_neighbors=k, metric=distance_metric, weights='distance')
        else:
            clf = KNeighborsClassifier(n_neighbors=k, metric=distance_metric)
        
        clf.fit(X_treino_Normalizado, Y_treino)
        y_pred = clf.predict(X_teste_Normalizado)
        accuracy = accuracy_score(Y_teste, y_pred)
        accuracies.append(accuracy)
        print(f"k={k}, Acurácia={accuracy:.4f}")
        
        # Analisar classificações incorretas
        incorrect_indices = np.where(y_pred != Y_teste)[0]
        if len(incorrect_indices) > 0:
            print(f"Classificações incorretas para k={k}:")
            for idx in incorrect_indices:
                print(f"Índice: {idx}, Classe Real: {Y_teste.iloc[idx]}, Predição: {y_pred[idx]}")
        
        # Mostrar matriz de confusão e relatório de classificação para k 
        if k == 2:
            print(f"\nMatriz de Confusão para k={k}:\n{confusion_matrix(Y_teste, y_pred)}")
            print(f"\nRelatório de Classificação para k={k}:\n{classification_report(Y_teste, y_pred)}")

    return accuracies

# %%
k_values = range(1, 11)

# Distância Euclidiana sem pesos
accuracies_euclidean = avaliar_knn(k_values, distance_metric='euclidean')
# Out:
# k=1, Acurácia=0.9419
# Classificações incorretas para k=1:
# Índice: 23, Classe Real: 0, Predição: 1
# Índice: 26, Classe Real: 0, Predição: 1
# Índice: 35, Classe Real: 0, Predição: 1
# Índice: 56, Classe Real: 0, Predição: 1
# Índice: 58, Classe Real: 0, Predição: 1
# k=2, Acurácia=0.9651
# Classificações incorretas para k=2:
# Índice: 23, Classe Real: 0, Predição: 1
# Índice: 26, Classe Real: 0, Predição: 1
# Índice: 56, Classe Real: 0, Predição: 1
#
# Matriz de Confusão para k=2:
# [[49  3]
#  [ 0 34]]
#
# Relatório de Classificação para k=2:
#               precision    recall  f1-score   support
#
#            0       1.00      0.94      0.97        52
#            1       0.92      1.00      0.96        34
#
#     accuracy                           0.97        86
#    macro avg       0.96      0.97      0.96        86
# weighted avg       0.97      0.97      0.97        86
#
# k=3, Acurácia=0.9302
# Classificações incorretas para k=3:
# Índice: 20, Classe Real: 0, Predição: 1
# Índice: 23, Classe Real: 0, Predição: 1
# Índice: 26, Classe Real: 0, Predição: 1
# Índice: 35, Classe Real: 0, Predição: 1
# Índice: 56, Classe Real: 0, Predição: 1
# Índice: 58, Classe Real: 0, Predição: 1
# k=4, Acurácia=0.9535
# Classificações incorretas para k=4:
# Índice: 23, Classe Real: 0, Predição: 1
# Índice: 26, Classe Real: 0, Predição: 1
# Índice: 35, Classe Real: 0, Predição: 1
# Índice: 57, Classe Real: 1, Predição: 0
# k=5, Acurácia=0.9419
# Classificações incorretas para k=5:
# Índice: 20, Classe Real: 0, Predição: 1
# Índice: 23, Classe Real: 0, Predição: 1
# Índice: 26, Classe Real: 0, Predição: 1
# Índice: 35, Classe Real: 0, Predição: 1
# Índice: 56, Classe Real: 0, Predição: 1
# k=6, Acurácia=0.9302
# Classificações incorretas para k=6:
# Índice: 20, Classe Real: 0, Predição: 1
# Índice: 23, Classe Real: 0, Predição: 1
# Índice: 26, Classe Real: 0, Predição: 1
# Índice: 35, Classe Real: 0, Predição: 1
# Índice: 56, Classe Real: 0, Predição: 1
# Índice: 57, Classe Real: 1, Predição: 0
# k=7, Acurácia=0.9302
# Classificações incorretas para k=7:
# Índice: 20, Classe Real: 0, Predição: 1
# Índice: 23, Classe Real: 0, Predição: 1
# Índice: 26, Classe Real: 0, Predição: 1
# Índice: 35, Classe Real: 0, Predição: 1
# Índice: 56, Classe Real: 0, Predição: 1
# Índice: 57, Classe Real: 1, Predição: 0
# k=8, Acurácia=0.9419
# Classificações incorretas para k=8:
# Índice: 23, Classe Real: 0, Predição: 1
# Índice: 26, Classe Real: 0, Predição: 1
# Índice: 35, Classe Real: 0, Predição: 1
# Índice: 56, Classe Real: 0, Predição: 1
# Índice: 57, Classe Real: 1, Predição: 0
# k=9, Acurácia=0.9419
# Classificações incorretas para k=9:
# Índice: 20, Classe Real: 0, Predição: 1
# Índice: 23, Classe Real: 0, Predição: 1
# Índice: 26, Classe Real: 0, Predição: 1
# Índice: 35, Classe Real: 0, Predição: 1
# Índice: 56, Classe Real: 0, Predição: 1
# k=10, Acurácia=0.9419
# Classificações incorretas para k=10:
# Índice: 20, Classe Real: 0, Predição: 1
# Índice: 23, Classe Real: 0, Predição: 1
# Índice: 26, Classe Real: 0, Predição: 1
# Índice: 35, Classe Real: 0, Predição: 1
# Índice: 56, Classe Real: 0, Predição: 1

# %%
# Distância Euclidiana com pesos
accuracies_euclidean_weights = avaliar_knn(k_values, distance_metric='euclidean', use_weights=True)
# Out:
# k=1, Acurácia=0.9419
# Classificações incorretas para k=1:
# Índice: 23, Classe Real: 0, Predição: 1
# Índice: 26, Classe Real: 0, Predição: 1
# Índice: 35, Classe Real: 0, Predição: 1
# Índice: 56, Classe Real: 0, Predição: 1
# Índice: 58, Classe Real: 0, Predição: 1
# k=2, Acurácia=0.9419
# Classificações incorretas para k=2:
# Índice: 23, Classe Real: 0, Predição: 1
# Índice: 26, Classe Real: 0, Predição: 1
# Índice: 35, Classe Real: 0, Predição: 1
# Índice: 56, Classe Real: 0, Predição: 1
# Índice: 58, Classe Real: 0, Predição: 1
# k=3, Acurácia=0.9302
# Classificações incorretas para k=3:
# Índice: 20, Classe Real: 0, Predição: 1
# Índice: 23, Classe Real: 0, Predição: 1
# Índice: 26, Classe Real: 0, Predição: 1
# Índice: 35, Classe Real: 0, Predição: 1
# Índice: 56, Classe Real: 0, Predição: 1
# Índice: 58, Classe Real: 0, Predição: 1
#
# Matriz de Confusão para k=3:
# [[46  6]
#  [ 0 34]]
#
# Relatório de Classificação para k=3:
#               precision    recall  f1-score   support
#
#            0       1.00      0.88      0.94        52
#            1       0.85      1.00      0.92        34
#
#     accuracy                           0.93        86
#    macro avg       0.93      0.94      0.93        86
# weighted avg       0.94      0.93      0.93        86
#
# k=4, Acurácia=0.9419
# Classificações incorretas para k=4:
# Índice: 23, Classe Real: 0, Predição: 1
# Índice: 26, Classe Real: 0, Predição: 1
# Índice: 35, Classe Real: 0, Predição: 1
# Índice: 56, Classe Real: 0, Predição: 1
# Índice: 58, Classe Real: 0, Predição: 1
# k=5, Acurácia=0.9419
# Classificações incorretas para k=5:
# Índice: 20, Classe Real: 0, Predição: 1
# Índice: 23, Classe Real: 0, Predição: 1
# Índice: 26, Classe Real: 0, Predição: 1
# Índice: 35, Classe Real: 0, Predição: 1
# Índice: 56, Classe Real: 0, Predição: 1
# k=6, Acurácia=0.9302
# Classificações incorretas para k=6:
# Índice: 20, Classe Real: 0, Predição: 1
# Índice: 23, Classe Real: 0, Predição: 1
# Índice: 26, Classe Real: 0, Predição: 1
# Índice: 35, Classe Real: 0, Predição: 1
# Índice: 56, Classe Real: 0, Predição: 1
# Índice: 58, Classe Real: 0, Predição: 1
# k=7, Acurácia=0.9302
# Classificações incorretas para k=7:
# Índice: 20, Classe Real: 0, Predição: 1
# Índice: 23, Classe Real: 0, Predição: 1
# Índice: 26, Classe Real: 0, Predição: 1
# Índice: 35, Classe Real: 0, Predição: 1
# Índice: 56, Classe Real: 0, Predição: 1
# Índice: 57, Classe Real: 1, Predição: 0
# k=8, Acurácia=0.9419
# Classificações incorretas para k=8:
# Índice: 23, Classe Real: 0, Predição: 1
# Índice: 26, Classe Real: 0, Predição: 1
# Índice: 35, Classe Real: 0, Predição: 1
# Índice: 56, Classe Real: 0, Predição: 1
# Índice: 58, Classe Real: 0, Predição: 1
# k=9, Acurácia=0.9419
# Classificações incorretas para k=9:
# Índice: 20, Classe Real: 0, Predição: 1
# Índice: 23, Classe Real: 0, Predição: 1
# Índice: 26, Classe Real: 0, Predição: 1
# Índice: 35, Classe Real: 0, Predição: 1
# Índice: 56, Classe Real: 0, Predição: 1
# k=10, Acurácia=0.9302
# Classificações incorretas para k=10:
# Índice: 20, Classe Real: 0, Predição: 1
# Índice: 23, Classe Real: 0, Predição: 1
# Índice: 26, Classe Real: 0, Predição: 1
# Índice: 35, Classe Real: 0, Predição: 1
# Índice: 56, Classe Real: 0, Predição: 1
# Índice: 58, Classe Real: 0, Predição: 1

# %%
# Distância Manhattan sem pesos
accuracies_manhattan = avaliar_knn(k_values, distance_metric='manhattan')
# Out:
# k=1, Acurácia=0.9419
# Classificações incorretas para k=1:
# Índice: 23, Classe Real: 0, Predição: 1
# Índice: 26, Classe Real: 0, Predição: 1
# Índice: 35, Classe Real: 0, Predição: 1
# Índice: 56, Classe Real: 0, Predição: 1
# Índice: 58, Classe Real: 0, Predição: 1
# k=2, Acurácia=0.9535
# Classificações incorretas para k=2:
# Índice: 23, Classe Real: 0, Predição: 1
# Índice: 35, Classe Real: 0, Predição: 1
# Índice: 56, Classe Real: 0, Predição: 1
# Índice: 57, Classe Real: 1, Predição: 0
# k=3, Acurácia=0.9419
# Classificações incorretas para k=3:
# Índice: 23, Classe Real: 0, Predição: 1
# Índice: 26, Classe Real: 0, Predição: 1
# Índice: 35, Classe Real: 0, Predição: 1
# Índice: 56, Classe Real: 0, Predição: 1
# Índice: 58, Classe Real: 0, Predição: 1
#
# Matriz de Confusão para k=3:
# [[47  5]
#  [ 0 34]]
#
# Relatório de Classificação para k=3:
#               precision    recall  f1-score   support
#
#            0       1.00      0.90      0.95        52
#            1       0.87      1.00      0.93        34
#
#     accuracy                           0.94        86
#    macro avg       0.94      0.95      0.94        86
# weighted avg       0.95      0.94      0.94        86
#
# k=4, Acurácia=0.9535
# Classificações incorretas para k=4:
# Índice: 23, Classe Real: 0, Predição: 1
# Índice: 26, Classe Real: 0, Predição: 1
# Índice: 35, Classe Real: 0, Predição: 1
# Índice: 56, Classe Real: 0, Predição: 1
# k=5, Acurácia=0.9302
# Classificações incorretas para k=5:
# Índice: 20, Classe Real: 0, Predição: 1
# Índice: 23, Classe Real: 0, Predição: 1
# Índice: 26, Classe Real: 0, Predição: 1
# Índice: 35, Classe Real: 0, Predição: 1
# Índice: 56, Classe Real: 0, Predição: 1
# Índice: 58, Classe Real: 0, Predição: 1
# k=6, Acurácia=0.9419
# Classificações incorretas para k=6:
# Índice: 23, Classe Real: 0, Predição: 1
# Índice: 26, Classe Real: 0, Predição: 1
# Índice: 35, Classe Real: 0, Predição: 1
# Índice: 56, Classe Real: 0, Predição: 1
# Índice: 57, Classe Real: 1, Predição: 0
# k=7, Acurácia=0.9186
# Classificações incorretas para k=7:
# Índice: 20, Classe Real: 0, Predição: 1
# Índice: 23, Classe Real: 0, Predição: 1
# Índice: 26, Classe Real: 0, Predição: 1
# Índice: 29, Classe Real: 0, Predição: 1
# Índice: 35, Classe Real: 0, Predição: 1
# Índice: 56, Classe Real: 0, Predição: 1
# Índice: 57, Classe Real: 1, Predição: 0
# k=8, Acurácia=0.9419
# Classificações incorretas para k=8:
# Índice: 23, Classe Real: 0, Predição: 1
# Índice: 26, Classe Real: 0, Predição: 1
# Índice: 35, Classe Real: 0, Predição: 1
# Índice: 56, Classe Real: 0, Predição: 1
# Índice: 57, Classe Real: 1, Predição: 0
# k=9, Acurácia=0.9302
# Classificações incorretas para k=9:
# Índice: 23, Classe Real: 0, Predição: 1
# Índice: 26, Classe Real: 0, Predição: 1
# Índice: 29, Classe Real: 0, Predição: 1
# Índice: 35, Classe Real: 0, Predição: 1
# Índice: 56, Classe Real: 0, Predição: 1
# Índice: 57, Classe Real: 1, Predição: 0
# k=10, Acurácia=0.9419
# Classificações incorretas para k=10:
# Índice: 23, Classe Real: 0, Predição: 1
# Índice: 26, Classe Real: 0, Predição: 1
# Índice: 35, Classe Real: 0, Predição: 1
# Índice: 56, Classe Real: 0, Predição: 1
# Índice: 57, Classe Real: 1, Predição: 0

# %%
# Distância Manhattan com pesos
accuracies_manhattan_weights = avaliar_knn(k_values, distance_metric='manhattan', use_weights=True)
# Out:
# k=1, Acurácia=0.9419
# Classificações incorretas para k=1:
# Índice: 23, Classe Real: 0, Predição: 1
# Índice: 26, Classe Real: 0, Predição: 1
# Índice: 35, Classe Real: 0, Predição: 1
# Índice: 56, Classe Real: 0, Predição: 1
# Índice: 58, Classe Real: 0, Predição: 1
# k=2, Acurácia=0.9419
# Classificações incorretas para k=2:
# Índice: 23, Classe Real: 0, Predição: 1
# Índice: 26, Classe Real: 0, Predição: 1
# Índice: 35, Classe Real: 0, Predição: 1
# Índice: 56, Classe Real: 0, Predição: 1
# Índice: 58, Classe Real: 0, Predição: 1
# k=3, Acurácia=0.9419
# Classificações incorretas para k=3:
# Índice: 23, Classe Real: 0, Predição: 1
# Índice: 26, Classe Real: 0, Predição: 1
# Índice: 35, Classe Real: 0, Predição: 1
# Índice: 56, Classe Real: 0, Predição: 1
# Índice: 58, Classe Real: 0, Predição: 1
#
# Matriz de Confusão para k=3:
# [[47  5]
#  [ 0 34]]
#
# Relatório de Classificação para k=3:
#               precision    recall  f1-score   support
#
#            0       1.00      0.90      0.95        52
#            1       0.87      1.00      0.93        34
#
#     accuracy                           0.94        86
#    macro avg       0.94      0.95      0.94        86
# weighted avg       0.95      0.94      0.94        86
#
# k=4, Acurácia=0.9419
# Classificações incorretas para k=4:
# Índice: 23, Classe Real: 0, Predição: 1
# Índice: 26, Classe Real: 0, Predição: 1
# Índice: 35, Classe Real: 0, Predição: 1
# Índice: 56, Classe Real: 0, Predição: 1
# Índice: 58, Classe Real: 0, Predição: 1
# k=5, Acurácia=0.9302
# Classificações incorretas para k=5:
# Índice: 20, Classe Real: 0, Predição: 1
# Índice: 23, Classe Real: 0, Predição: 1
# Índice: 26, Classe Real: 0, Predição: 1
# Índice: 35, Classe Real: 0, Predição: 1
# Índice: 56, Classe Real: 0, Predição: 1
# Índice: 58, Classe Real: 0, Predição: 1
# k=6, Acurácia=0.9419
# Classificações incorretas para k=6:
# Índice: 23, Classe Real: 0, Predição: 1
# Índice: 26, Classe Real: 0, Predição: 1
# Índice: 35, Classe Real: 0, Predição: 1
# Índice: 56, Classe Real: 0, Predição: 1
# Índice: 58, Classe Real: 0, Predição: 1
# k=7, Acurácia=0.9186
# Classificações incorretas para k=7:
# Índice: 20, Classe Real: 0, Predição: 1
# Índice: 23, Classe Real: 0, Predição: 1
# Índice: 26, Classe Real: 0, Predição: 1
# Índice: 29, Classe Real: 0, Predição: 1
# Índice: 35, Classe Real: 0, Predição: 1
# Índice: 56, Classe Real: 0, Predição: 1
# Índice: 57, Classe Real: 1, Predição: 0
# k=8, Acurácia=0.9419
# Classificações incorretas para k=8:
# Índice: 23, Classe Real: 0, Predição: 1
# Índice: 26, Classe Real: 0, Predição: 1
# Índice: 35, Classe Real: 0, Predição: 1
# Índice: 56, Classe Real: 0, Predição: 1
# Índice: 57, Classe Real: 1, Predição: 0
# k=9, Acurácia=0.9302
# Classificações incorretas para k=9:
# Índice: 23, Classe Real: 0, Predição: 1
# Índice: 26, Classe Real: 0, Predição: 1
# Índice: 29, Classe Real: 0, Predição: 1
# Índice: 35, Classe Real: 0, Predição: 1
# Índice: 56, Classe Real: 0, Predição: 1
# Índice: 57, Classe Real: 1, Predição: 0
# k=10, Acurácia=0.9535
# Classificações incorretas para k=10:
# Índice: 23, Classe Real: 0, Predição: 1
# Índice: 26, Classe Real: 0, Predição: 1
# Índice: 35, Classe Real: 0, Predição: 1
# Índice: 56, Classe Real: 0, Predição: 1

# %%
# resultados
plt.figure(figsize=(12, 8))

plt.plot(k_values, accuracies_euclidean, marker='o', label='Euclidiana')
plt.plot(k_values, accuracies_euclidean_weights, marker='o', label='Euclidiana com Pesos')
plt.plot(k_values, accuracies_manhattan, marker='o', label='Manhattan')
plt.plot(k_values, accuracies_manhattan_weights, marker='o', label='Manhattan com Pesos')

plt.xlabel('Número de Vizinhos k')
plt.ylabel('Acurácia')
plt.title('Acurácia do k-NN Variando o Valor de k e Medidas de Distância')
plt.legend()
plt.grid(True)
plt.show()
